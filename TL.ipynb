# %% [markdown]
# <a href="https://colab.research.google.com/github/Azka-Yasin/Breast_Cancer_Project_20s20041/blob/main/TL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    confusion_matrix,
    precision_score,
    recall_score,
    classification_report,
)
from tensorflow import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50, VGG16, Xception
from keras.layers import GlobalAveragePooling2D

# Preprocess images using ImageDataGenerator
def preprocessing_images(path, target_size=(227, 227), augmentation=False):
    if augmentation:
        image_data = ImageDataGenerator(
            zoom_range=0.2,
            shear_range=0.2,
            rescale=1/255,
            horizontal_flip=True,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            fill_mode='nearest'
        )
    else:
        image_data = ImageDataGenerator(rescale=1/255)

    image_generator = image_data.flow_from_directory(
        directory=path,
        target_size=target_size,
        batch_size=32,
        class_mode='binary'
    )

    return image_generator

# Function to create a model based on the specified architecture
def create_model(architecture, input_shape):
    if architecture == 'ResNet50':
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    elif architecture == 'VGG16':
        base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    elif architecture == 'Xception':
        base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)
    else:
        raise ValueError(f"Unsupported architecture: {architecture}")

    model = Sequential()
    model.add(base_model)
    model.add(GlobalAveragePooling2D())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(1, activation='sigmoid'))

    return model

# Specify paths
train_path = r"/content/drive/MyDrive/ddsm/train"
test_path = r"/content/drive/MyDrive/ddsm/test"
val_path = r"/content/drive/MyDrive/ddsm/val"

# Data augmentation for training but not for validation set
train_data = preprocessing_images(train_path, target_size=(224, 224), augmentation=True)
val_data = preprocessing_images(val_path, target_size=(224, 224), augmentation=False)

# List of architectures to try
architectures = ['ResNet50', 'VGG16', 'Xception']

for architecture in architectures:
    # Model definition
    input_shape = (224, 224, 3)
    model = create_model(architecture, input_shape)

    model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

    #early stopping
    es= EarlyStopping(monitor="val_accuracy", min_delta=0.01, patience=10, verbose=1, mode='auto')

    # Model checkpoint
    mc = ModelCheckpoint(
        monitor="val_accuracy",
        filepath=f"./21jan-ddsm-bestmodel-{architecture}.h5",
        verbose=1,
        save_best_only=True,
        mode='auto',
        save_freq='epoch'
    )

    # Learning rate scheduler function
    def lr_schedule(epoch):
        learning_rate = 1e-4
        if epoch > 30:
            learning_rate *= 1e-1
        return learning_rate

    # Learning rate scheduler callback
    lr_scheduler = LearningRateScheduler(lr_schedule)

    # Training
    history = model.fit(
        train_data,
        steps_per_epoch=264,
        epochs=50,
        verbose=1,
        validation_data=val_data,
        validation_steps=57,
        callbacks=[mc, lr_scheduler, es]
    )

    # Save the best model
    model.save(f"/content/21jan-ddsm-bestmodel-{architecture}.h5")
    from google.colab import files
    # Download the best model
    files.download(f"/content/21jan-ddsm-bestmodel-{architecture}.h5")

    # Visualizations
    # Training vs Validation Loss Graph
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'Training vs Validation Loss - {architecture}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig(f"/content/drive/MyDrive/ddsm/training_vs_validation_loss_21j_{architecture}.png")
    plt.show()

    # Learning Curve
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'Training vs Validation Accuracy - {architecture}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig(f"/content/drive/MyDrive/ddsm/training_vs_validation_accuracy_21j_{architecture}.png")
    plt.show()

    # Load the best model
    model = load_model(f"/content/21jan-ddsm-bestmodel-{architecture}.h5")
    # Evaluation on the Test Set
    # Create an ImageDataGenerator for rescaling
    test_data = ImageDataGenerator(rescale=1 / 255)

    test_generator = test_data.flow_from_directory(
        directory=test_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode=None,  # Set to None for the test set
        shuffle=False
    )

    # Calculate the number of steps for evaluation
    test_steps = int(np.ceil(test_generator.samples / test_generator.batch_size))

    # Evaluate the model
    test_loss, test_accuracy = model.evaluate(test_generator, steps=test_steps)

    # Predictions
    y_pred = model.predict(test_generator, steps=test_steps)
    y_true = test_generator.classes.astype(float)

    # Metrics
    accuracy = accuracy_score(y_true, np.round(y_pred))
    precision = precision_score(y_true, np.round(y_pred))
    recall = recall_score(y_true, np.round(y_pred))
    f1 = f1_score(y_true, np.round(y_pred))
    auc_roc = metrics.roc_auc_score(y_true, y_pred)

    print(f"\nMetrics for {architecture}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"AUC-ROC: {auc_roc:.4f}")

    # Confusion Matrix
    conf_matrix = confusion_matrix(y_true, np.round(y_pred))
    print("Confusion Matrix:")
    print(conf_matrix)

    # Classification Report
    class_report = classification_report(y_true, np.round(y_pred), target_names=['benign', 'malignant'])
    print("Classification Report:")
    print(class_report)

    # Heatmap
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['0', '1'], yticklabels=['0', '1'])
    plt.title(f'Confusion Matrix Heatmap - {architecture}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
# Out:
# Found 8443 images belonging to 2 classes.
# Found 1808 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Epoch 1/50
# 264/264 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9081
# Epoch 1: val_accuracy improved from -inf to 0.48341, saving model to ./21jan-ddsm-bestmodel-ResNet50.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 264/264 [==============================] - 2270s 8s/step - loss: 0.2085 - accuracy: 0.9081 - val_loss: 0.6972 - val_accuracy: 0.4834 - lr: 1.0000e-04
# Epoch 2/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9678
# Epoch 2: val_accuracy improved from 0.48341 to 0.63993, saving model to ./21jan-ddsm-bestmodel-ResNet50.h5
# 264/264 [==============================] - 189s 717ms/step - loss: 0.0880 - accuracy: 0.9678 - val_loss: 0.6048 - val_accuracy: 0.6399 - lr: 1.0000e-04
# Epoch 3/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9784
# Epoch 3: val_accuracy improved from 0.63993 to 0.77987, saving model to ./21jan-ddsm-bestmodel-ResNet50.h5
# 264/264 [==============================] - 188s 709ms/step - loss: 0.0597 - accuracy: 0.9784 - val_loss: 0.4132 - val_accuracy: 0.7799 - lr: 1.0000e-04
# Epoch 4/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9877
# Epoch 4: val_accuracy improved from 0.77987 to 0.87721, saving model to ./21jan-ddsm-bestmodel-ResNet50.h5
# 264/264 [==============================] - 190s 719ms/step - loss: 0.0368 - accuracy: 0.9877 - val_loss: 0.2857 - val_accuracy: 0.8772 - lr: 1.0000e-04
# Epoch 5/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9917
# Epoch 5: val_accuracy improved from 0.87721 to 0.99502, saving model to ./21jan-ddsm-bestmodel-ResNet50.h5
# 264/264 [==============================] - 192s 725ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 0.0216 - val_accuracy: 0.9950 - lr: 1.0000e-04
# Epoch 6/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9882
# Epoch 6: val_accuracy improved from 0.99502 to 0.99834, saving model to ./21jan-ddsm-bestmodel-ResNet50.h5
# 264/264 [==============================] - 190s 715ms/step - loss: 0.0364 - accuracy: 0.9882 - val_loss: 0.0115 - val_accuracy: 0.9983 - lr: 1.0000e-04
# Epoch 7/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9935
# Epoch 7: val_accuracy did not improve from 0.99834
# 264/264 [==============================] - 187s 707ms/step - loss: 0.0210 - accuracy: 0.9935 - val_loss: 0.2560 - val_accuracy: 0.8988 - lr: 1.0000e-04
# Epoch 8/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9921
# Epoch 8: val_accuracy did not improve from 0.99834
# 264/264 [==============================] - 187s 708ms/step - loss: 0.0233 - accuracy: 0.9921 - val_loss: 0.0319 - val_accuracy: 0.9873 - lr: 1.0000e-04
# Epoch 9/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9906
# Epoch 9: val_accuracy did not improve from 0.99834
# 264/264 [==============================] - 188s 710ms/step - loss: 0.0290 - accuracy: 0.9906 - val_loss: 2.9643 - val_accuracy: 0.5680 - lr: 1.0000e-04
# Epoch 10/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9923
# Epoch 10: val_accuracy did not improve from 0.99834
# 264/264 [==============================] - 188s 711ms/step - loss: 0.0228 - accuracy: 0.9923 - val_loss: 0.2620 - val_accuracy: 0.9115 - lr: 1.0000e-04
# Epoch 11/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9941
# Epoch 11: val_accuracy improved from 0.99834 to 1.00000, saving model to ./21jan-ddsm-bestmodel-ResNet50.h5
# 264/264 [==============================] - 187s 708ms/step - loss: 0.0161 - accuracy: 0.9941 - val_loss: 7.7965e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 12/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9940
# Epoch 12: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 186s 706ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.0981 - val_accuracy: 0.9657 - lr: 1.0000e-04
# Epoch 13/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9921
# Epoch 13: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 183s 694ms/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.0081 - val_accuracy: 0.9989 - lr: 1.0000e-04
# Epoch 14/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9953
# Epoch 14: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 184s 696ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.0136 - val_accuracy: 0.9961 - lr: 1.0000e-04
# Epoch 15/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9931
# Epoch 15: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 183s 694ms/step - loss: 0.0191 - accuracy: 0.9931 - val_loss: 0.0528 - val_accuracy: 0.9823 - lr: 1.0000e-04
# Epoch 15: early stopping
# Found 1807 images belonging to 2 classes.
# 57/57 [==============================] - 318s 6s/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# 57/57 [==============================] - 12s 198ms/step
#
# Metrics for ResNet50:
# Accuracy: 0.9862
# Precision: 0.9911
# Recall: 0.9814
# F1 Score: 0.9862
# AUC-ROC: 0.9994
# Confusion Matrix:
# [[887   8]
#  [ 17 895]]
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.98      0.99      0.99       895
#    malignant       0.99      0.98      0.99       912
#
#     accuracy                           0.99      1807
#    macro avg       0.99      0.99      0.99      1807
# weighted avg       0.99      0.99      0.99      1807
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.5084
# Epoch 1: val_accuracy improved from -inf to 0.50442, saving model to ./21jan-ddsm-bestmodel-VGG16.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 264/264 [==============================] - 237s 802ms/step - loss: 0.6962 - accuracy: 0.5084 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 2/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5082
# Epoch 2: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 188s 711ms/step - loss: 0.6927 - accuracy: 0.5082 - val_loss: 0.6932 - val_accuracy: 0.4956 - lr: 1.0000e-04
# Epoch 3/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4941
# Epoch 3: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 188s 710ms/step - loss: 0.6932 - accuracy: 0.4941 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 4/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4984
# Epoch 4: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 185s 701ms/step - loss: 0.6931 - accuracy: 0.4984 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 5/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5005
# Epoch 5: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 187s 709ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 6/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5038
# Epoch 6: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 186s 704ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 7/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5038
# Epoch 7: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 187s 707ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 8/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5038
# Epoch 8: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 187s 706ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 9/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5038
# Epoch 9: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 187s 706ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 10/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5038
# Epoch 10: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 186s 702ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 11/50
# 264/264 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5038
# Epoch 11: val_accuracy did not improve from 0.50442
# 264/264 [==============================] - 187s 709ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 11: early stopping
# Found 1807 images belonging to 2 classes.
# 57/57 [==============================] - 8s 146ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# 57/57 [==============================] - 15s 258ms/step
#
# Metrics for VGG16:
# Accuracy: 0.5047
# Precision: 0.5047
# Recall: 1.0000
# F1 Score: 0.6708
# AUC-ROC: 0.5000
# Confusion Matrix:
# [[  0 895]
#  [  0 912]]
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.00      0.00      0.00       895
#    malignant       0.50      1.00      0.67       912
#
#     accuracy                           0.50      1807
#    macro avg       0.25      0.50      0.34      1807
# weighted avg       0.25      0.50      0.34      1807
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step
# Epoch 1/50
# 264/264 [==============================] - ETA: 0s - loss: 0.2363 - accuracy: 0.8921
# Epoch 1: val_accuracy improved from -inf to 0.96184, saving model to ./21jan-ddsm-bestmodel-Xception.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 264/264 [==============================] - 236s 778ms/step - loss: 0.2363 - accuracy: 0.8921 - val_loss: 0.0869 - val_accuracy: 0.9618 - lr: 1.0000e-04
# Epoch 2/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9704
# Epoch 2: val_accuracy improved from 0.96184 to 0.99723, saving model to ./21jan-ddsm-bestmodel-Xception.h5
# 264/264 [==============================] - 199s 752ms/step - loss: 0.0771 - accuracy: 0.9704 - val_loss: 0.0290 - val_accuracy: 0.9972 - lr: 1.0000e-04
# Epoch 3/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9837
# Epoch 3: val_accuracy did not improve from 0.99723
# 264/264 [==============================] - 198s 748ms/step - loss: 0.0448 - accuracy: 0.9837 - val_loss: 0.0441 - val_accuracy: 0.9856 - lr: 1.0000e-04
# Epoch 4/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9861
# Epoch 4: val_accuracy improved from 0.99723 to 1.00000, saving model to ./21jan-ddsm-bestmodel-Xception.h5
# 264/264 [==============================] - 198s 751ms/step - loss: 0.0370 - accuracy: 0.9861 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 5/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9898
# Epoch 5: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 198s 746ms/step - loss: 0.0330 - accuracy: 0.9898 - val_loss: 0.0859 - val_accuracy: 0.9591 - lr: 1.0000e-04
# Epoch 6/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9912
# Epoch 6: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 197s 746ms/step - loss: 0.0234 - accuracy: 0.9912 - val_loss: 0.0229 - val_accuracy: 0.9928 - lr: 1.0000e-04
# Epoch 7/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9929
# Epoch 7: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 198s 749ms/step - loss: 0.0229 - accuracy: 0.9929 - val_loss: 0.0349 - val_accuracy: 0.9878 - lr: 1.0000e-04
# Epoch 8/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9931
# Epoch 8: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 197s 746ms/step - loss: 0.0192 - accuracy: 0.9931 - val_loss: 0.2657 - val_accuracy: 0.9176 - lr: 1.0000e-04
# Epoch 9/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9931
# Epoch 9: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 197s 745ms/step - loss: 0.0192 - accuracy: 0.9931 - val_loss: 0.0204 - val_accuracy: 0.9939 - lr: 1.0000e-04
# Epoch 10/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9959
# Epoch 10: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 197s 744ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.0673 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 11/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9954
# Epoch 11: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 198s 748ms/step - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.0524 - val_accuracy: 0.9812 - lr: 1.0000e-04
# Epoch 12/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9953
# Epoch 12: val_accuracy did not improve from 1.00000
# 264/264 [==============================] - 197s 746ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.0570 - val_accuracy: 0.9773 - lr: 1.0000e-04
# Epoch 12: early stopping
# Found 1807 images belonging to 2 classes.
# 57/57 [==============================] - 10s 159ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# 57/57 [==============================] - 14s 233ms/step
#
# Metrics for Xception:
# Accuracy: 0.9817
# Precision: 0.9878
# Recall: 0.9759
# F1 Score: 0.9818
# AUC-ROC: 0.9985
# Confusion Matrix:
# [[884  11]
#  [ 22 890]]
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.98      0.99      0.98       895
#    malignant       0.99      0.98      0.98       912
#
#     accuracy                           0.98      1807
#    macro avg       0.98      0.98      0.98      1807
# weighted avg       0.98      0.98      0.98      1807
